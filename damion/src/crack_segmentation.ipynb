# %% [markdown]
# # Crack_Segmentation with UNet
# ## dataset https://www.kaggle.com/datasets/lakshaymiddha/crack-segmentation-dataset?resource=download

# %%
import glob
import os
import cv2
import pandas as pd
import numpy as np
import math
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Data_load

# %%
def train_data_loading(train_path,image_size = 512):

    out_rows = image_size
    out_cols = image_size
    
    img_path = train_path + '/images'
    mask_path = train_path + '/masks'
    
    print('-'*30)
    print('Creating training images...')
    print('-'*30)
    
    imgs = glob.glob(img_path +"/*.jpg")
    labels = glob.glob(mask_path +"/*.jpg")
    imgdatas = np.ndarray((len(imgs),out_rows,out_cols,1), dtype=np.uint8)
    imglabels = np.ndarray((len(imgs),out_rows,out_cols,1), dtype=np.uint8)
    imgnames=[]
    
    for i, imgname in enumerate(imgs):
        if i%100==0:
            print('{}/{}'.format(i, len(imgs)))
        name = os.path.split(imgname)[1][:-4]
        img = load_img(imgname, color_mode = "grayscale")
        labelname= mask_path + '/' + os.path.split(imgname)[1]
        label = load_img(labelname, color_mode = "grayscale")
        img=img.resize((out_rows,out_cols))
        label=label.resize((out_rows,out_cols))

        img = img_to_array(img)
        label = img_to_array(label)
        imgdatas[i] = img
        imglabels[i] = label
        imgnames.append(name)

    imgdatas = imgdatas.astype('float32')
    imglabels = imglabels.astype('float32')
    
    print('img : ', imgdatas.max())
    print('mask : ',imglabels.max())
    
    print('-'*30)
    print('normalization start...')
    print('-'*30)
    imgdatas = imgdatas/255.0
    
    imglabels[imglabels <= 127] = 0
    imglabels[imglabels > 127] = 1
    
    print('img : ',imgdatas.max())
    print('mask : ',imglabels.max())
    print('mask : ',imglabels.min())
    print('loading done')
    
    return imgdatas, imglabels, imgnames

# %% [markdown]
# ## Function

# %%
def mkfolder(folder):
    if not os.path.lexists(folder):
        os.makedirs(folder)
    

def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def dice_coef_loss(y_true, y_pred):
        return 1-dice_coef(y_true, y_pred)

def sens(y_true, y_pred): # sensitivity, recall
    print(y_pred)
    print(y_true)
    y_target_yn = K.round(K.clip(y_true, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall

def sch(epoch):
    if epoch>100 and epoch<=250:
        return 0.0001
    elif epoch>250:
        return 0.00001
    else:
        return 0.001

# %% [markdown]
# # Model Shape

# %%
def get_unet(img_rows, img_cols):
    inputs = Input((img_rows, img_cols,1))
    conv1 = Conv2D(32, (3, 3), activation=None, padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv1 = Conv2D(32, (3, 3), activation=None, padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation=None, padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Conv2D(64, (3, 3), activation=None, padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation=None, padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    conv3 = Conv2D(128, (3, 3), activation=None, padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation=None, padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    conv4 = Conv2D(256, (3, 3), activation=None, padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation=None, padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)
    conv5 = Conv2D(512, (3, 3), activation=None, padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation=None, padding='same')(up6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)
    conv6 = Conv2D(256, (3, 3), activation=None, padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation=None, padding='same')(up7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)
    conv7 = Conv2D(128, (3, 3), activation=None, padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation=None, padding='same')(up8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    conv8 = Conv2D(64, (3, 3), activation=None, padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation=None, padding='same')(up9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)
    conv9 = Conv2D(32, (3, 3), activation=None, padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=inputs, outputs=conv10)

    return model

# %% [markdown]
# ## CosineDecayRestarts Callbacks

# %%
class CosineAnnealingWarmup(tf.keras.callbacks.Callback):
    def __init__(self, epochs_per_cycle,iteration, max_lr, min_lr, verbose = 1):
        self.epochs_per_cycle = epochs_per_cycle
        self.max_lr = max_lr
        self.min_lr = min_lr
        self.iteration = iteration;
        self.steps = 0;
        self.learning_rate = max_lr;
        self.epochs = 0; # epoch to search min_lr for each iteration 
        self.warmup_epoch = 10  # warmup epcch
        self.verbose = verbose # log
        self.lrates = list() # for graph
        
        
    def cosine_annealing(self, epoch, epochs_per_cycle, max_lr):
        self.epochs += 1; 
        cos_inner = (math.pi * (self.epochs % epochs_per_cycle)) / (epochs_per_cycle)
        self.learning_rate = max_lr/2 * (math.cos(cos_inner) + 1)
        
        if ((self.epochs % epochs_per_cycle) == (epochs_per_cycle-1)):
            self.steps += 1
            self.max_lr *= 0.8
            self.epochs = 0;
            self.epochs_per_cycle = math.floor(self.epochs_per_cycle*1.2)
            
        return max_lr/2 * (math.cos(cos_inner) + 1)
  
    def warm_up(self, epoch):
        
        self.learning_rate = self.max_lr * epoch / self.warmup_epoch
        
        return self.learning_rate

    # calculate and set learning rate at the start of the epoch
    def on_epoch_begin(self, epoch, logs = None):
        if (epoch < self.warmup_epoch):
            # warm up learning rate
            lr = self.warm_up(epoch)
       
        elif(self.steps < self.iteration):
            # calculate learning rate
            lr = self.cosine_annealing(epoch, self.epochs_per_cycle, self.max_lr)
            
        else:
            lr = self.min_lr
        
        if (self.verbose == 1):
            print('\nEpoch %05d: CosineAnnealingScheduler setting learng rate to %s.' % (epoch + 1, lr))  

        
        K.set_value(self.model.optimizer.lr, lr)

#         self.lrates.append(lr)

# %% [markdown]
# # Train

# %%
def deep(imgs_train, imgs_mask_train, path, batch_size = 4, epochs = 10, image_size=512, model = None): 

    if (model == None):
        model = get_unet(image_size, image_size)
    
    model.compile(optimizer=Adam(lr=0.001), loss=dice_coef_loss, 
                        metrics=['accuracy', sens, dice_coef_loss])
    
    check_model_path = path+'/crack_check'
    predict_path = path+'/crack_pred'
    mkfolder(check_model_path)
    mkfolder(predict_path)

    model_checkpoint = ModelCheckpoint(check_model_path + '/final_{epoch:d}_{loss:f}.hdf5', 
                                        monitor='val_dice_coef_loss',verbose=1, 
                                        save_best_only=False)
#     earlystopping = EarlyStopping(monitor='val_dice_coef_loss', patience=30, restore_best_weights=True)
#     cosine_schedule = CosineAnnealingWarmup(epochs_per_cycle=25, iteration=2,max_lr = 1e-3, min_lr = 1e-6)
    
    print('Fitting model...')
    model.fit(imgs_train, imgs_mask_train, batch_size=batch_size, validation_split=0.1,epochs=epochs, verbose=1,shuffle=True, callbacks = [model_checkpoint])
    print('save model')
    model.save(predict_path + '/final.h5')
    return model

# %% [markdown]
# # Predict

# %%
def predict_save(pred_list,name_list,test_path):
    
    print('-'*30)
    print('Saving test images...')
    print('-'*30)
    
    pred_img_path = test_path + '/pred'
    mkfolder(pred_img_path)

    imgs = pred_list
    for i in range(imgs.shape[0]):
        img = imgs[i]
        img[img <= 0.5] = 0
        img[img > 0.5] = 255
        img = array_to_img(img)
        img.save(pred_img_path+"/%s_pred.jpg" %(name_list[i]))

def predict_val(model,test_path,image_size=512):
    
    imgs_test, imgs_label_test, test_name = create_test_data(test_path, image_size, image_size)
    print('predict test data')
    
    imgs_label_pred = model.predict(imgs_test, batch_size=4, verbose=1)
    name_list=test_name
    df = pd.DataFrame(columns=['name', 'acc', 'sen', 'spe', 'dsc'],dtype = float)
    df = df.astype({'name': 'str'})

    true_list=imgs_label_test
    print(true_list.shape)

    pred_list=imgs_label_pred
    print(np.unique(pred_list))
    pred_list[pred_list > 0.5] = 1
    pred_list[pred_list <= 0.5] = 0
    
#     sensitivity=[]
#     specificity=[]
#     acc=[]
#     dsc=[]

#     for i in range(len(true_list)):
#         yt=true_list[i].flatten()
#         yp=pred_list[i].flatten()
#         mat=confusion_matrix(yt,yp)
#         if len(mat) == 2:
#             ac=(mat[1,1]+mat[0,0])/(mat[1,0]+mat[1,1]+mat[0,1]+mat[0,0])
#             st=mat[1,1]/(mat[1,0]+mat[1,1])
#             sp=mat[0,0]/(mat[0,1]+mat[0,0])
#             if mat[1,0]+mat[1,1] == 0:
#                 specificity.append(sp)
#                 acc.append(ac)
#             else:
#                 sensitivity.append(st)  
#                 specificity.append(sp)
#                 acc.append(ac)
#         else:
#             specificity.append(1)
#             acc.append(1)

#         yt=true_list[i]
#         yp=pred_list[i]
#         if np.sum(yt) != 0 and np.sum(yp) != 0:
#             dice = np.sum(yp[yt==1])*2.0 / (np.sum(yt) + np.sum(yp))
#             dsc.append(dice)
#             df=  df.append({'name':name_list[i], 'acc':ac, 'sen':st, 'spe':sp, 'dsc':dice}, ignore_index=True)

#     print("complete")      
#     print("acc avg : {0:0.4f}".format(np.mean(acc)))
#     print("sensitivity avg : {0:0.4f}".format(np.mean(sensitivity)))
#     print("specificity avg : {0:0.4f}".format(np.mean(specificity)))
#     print("dsc avg : {0:0.4f}".format(np.mean(dsc)))
    
    

    predict_save(pred_list,name_list,test_path)
    return test_name

# %%
def create_test_data(test_path, out_rows, out_cols):
    
    img_path = test_path + '/images'
    mask_path = test_path + '/masks'
    
    print('-'*30)
    print('Creating test images...')
    print('-'*30)
    
    imgs = glob.glob(img_path +"/*.jpg")
    labels = glob.glob(mask_path +"/*.jpg")
    imgdatas = np.ndarray((len(imgs),out_rows,out_cols,1), dtype=np.uint8)
    imglabels = np.ndarray((len(imgs),out_rows,out_cols,1), dtype=np.uint8)
    imgnames=[]
    
    for i, imgname in enumerate(imgs):
        if i%100==0:
            print('{}/{}'.format(i, len(imgs)))
        name = os.path.split(imgname)[1][:-4]
        img = load_img(imgname, color_mode = "grayscale")
        labelname= mask_path + '/' + os.path.split(imgname)[1]
        label = load_img(labelname, color_mode = "grayscale")
        img=img.resize((out_rows,out_cols))
        label=label.resize((out_rows,out_cols))

        img = img_to_array(img)
        label = img_to_array(label)
        imgdatas[i] = img
        imglabels[i] = label
        imgnames.append(name)

    imgdatas = imgdatas.astype('float32')
    imglabels = imglabels.astype('float32')
    
    print('img : ', imgdatas.max())
    print('mask : ',imglabels.max())
    
    print('-'*30)
    print('normalization start...')
    print('-'*30)
    imgdatas = imgdatas/255.0
    
    imglabels[imglabels <= 127] = 0
    imglabels[imglabels > 127] = 1
    
    print('img : ',imgdatas.max())
    print('mask : ',imglabels.max())
    print('mask : ',imglabels.min())
    print('loading done')
    
    return imgdatas, imglabels, imgnames

# %% [markdown]
# # Main

# %%
def main():
    # 주어진 Train Dataset 경로.
    path = 'C:/Users/s_wnsgk4041/crack_segmentation_dataset'
    train_path = 'C:/Users/s_wnsgk4041/crack_segmentation_dataset/train'
    test_path = 'C:/Users/s_wnsgk4041/crack_segmentation_dataset/test'
    image_size = 512
    epochs = 50
    batch_sizes = 4
    
    imgs_train, imgs_mask_train, imgs_name = train_data_loading(train_path, image_size = image_size)
    
    model = load_model('C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check/final_20_0.176055.hdf5',
                                       custom_objects={'sens':sens,'dice_coef_loss': dice_coef_loss})
    
    model = deep(imgs_train, imgs_mask_train, path, batch_size = batch_sizes, epochs = epochs, image_size=image_size, model=model)

    test_name = predict_val(model, test_path, image_size = image_size)
    
if __name__ == "__main__":
    main()
# Out:
# ------------------------------
# Creating training images...
# ------------------------------
# 0/9603
# 100/9603
# 200/9603
# 300/9603
# 400/9603
# 500/9603
# 600/9603
# 700/9603
# 800/9603
# 900/9603
# 1000/9603
# 1100/9603
# 1200/9603
# 1300/9603
# 1400/9603
# 1500/9603
# 1600/9603
# 1700/9603
# 1800/9603
# 1900/9603
# 2000/9603
# 2100/9603
# 2200/9603
# 2300/9603
# 2400/9603
# 2500/9603
# 2600/9603
# 2700/9603
# 2800/9603
# 2900/9603
# 3000/9603
# 3100/9603
# 3200/9603
# 3300/9603
# 3400/9603
# 3500/9603
# 3600/9603
# 3700/9603
# 3800/9603
# 3900/9603
# 4000/9603
# 4100/9603
# 4200/9603
# 4300/9603
# 4400/9603
# 4500/9603
# 4600/9603
# 4700/9603
# 4800/9603
# 4900/9603
# 5000/9603
# 5100/9603
# 5200/9603
# 5300/9603
# 5400/9603
# 5500/9603
# 5600/9603
# 5700/9603
# 5800/9603
# 5900/9603
# 6000/9603
# 6100/9603
# 6200/9603
# 6300/9603
# 6400/9603
# 6500/9603
# 6600/9603
# 6700/9603
# 6800/9603
# 6900/9603
# 7000/9603
# 7100/9603
# 7200/9603
# 7300/9603
# 7400/9603
# 7500/9603
# 7600/9603
# 7700/9603
# 7800/9603
# 7900/9603
# 8000/9603
# 8100/9603
# 8200/9603
# 8300/9603
# 8400/9603
# 8500/9603
# 8600/9603
# 8700/9603
# 8800/9603
# 8900/9603
# 9000/9603
# 9100/9603
# 9200/9603
# 9300/9603
# 9400/9603
# 9500/9603
# 9600/9603
# img :  255.0
# mask :  255.0
# ------------------------------
# normalization start...
# ------------------------------
# img :  1.0
# mask :  1.0
# mask :  0.0
# loading done
# Fitting model...
# Epoch 1/50
# Tensor("model/conv2d_18/Sigmoid:0", shape=(None, 512, 512, 1), dtype=float32)
# Tensor("IteratorGetNext:1", shape=(None, 512, 512, 1), dtype=float32)
# Tensor("model/conv2d_18/Sigmoid:0", shape=(None, 512, 512, 1), dtype=float32)
# Tensor("IteratorGetNext:1", shape=(None, 512, 512, 1), dtype=float32)
# 2161/2161 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 0.9900 - sens: 0.8191 - dice_coef_loss: 0.1760Tensor("model/conv2d_18/Sigmoid:0", shape=(None, 512, 512, 1), dtype=float32)
# Tensor("IteratorGetNext:1", shape=(None, 512, 512, 1), dtype=float32)
# 2161/2161 [==============================] - 796s 359ms/step - loss: 0.1760 - accuracy: 0.9900 - sens: 0.8191 - dice_coef_loss: 0.1760 - val_loss: 0.4280 - val_accuracy: 0.9693 - val_sens: 0.4351 - val_dice_coef_loss: 0.4277
#
# Epoch 00001: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_1_0.176616.hdf5
# Epoch 2/50
# 2161/2161 [==============================] - 772s 357ms/step - loss: 0.1786 - accuracy: 0.9898 - sens: 0.8156 - dice_coef_loss: 0.1786 - val_loss: 0.4544 - val_accuracy: 0.9681 - val_sens: 0.4087 - val_dice_coef_loss: 0.4541
#
# Epoch 00002: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_2_0.176946.hdf5
# Epoch 3/50
# 2161/2161 [==============================] - 771s 357ms/step - loss: 0.1742 - accuracy: 0.9900 - sens: 0.8214 - dice_coef_loss: 0.1742 - val_loss: 0.4188 - val_accuracy: 0.9693 - val_sens: 0.4511 - val_dice_coef_loss: 0.4186
#
# Epoch 00003: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_3_0.174983.hdf5
# Epoch 4/50
# 2161/2161 [==============================] - 772s 357ms/step - loss: 0.1735 - accuracy: 0.9900 - sens: 0.8193 - dice_coef_loss: 0.1735 - val_loss: 0.4598 - val_accuracy: 0.9680 - val_sens: 0.4015 - val_dice_coef_loss: 0.4596
#
# Epoch 00004: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_4_0.172449.hdf5
# Epoch 5/50
# 2161/2161 [==============================] - 771s 357ms/step - loss: 0.1701 - accuracy: 0.9902 - sens: 0.8245 - dice_coef_loss: 0.1701 - val_loss: 0.4457 - val_accuracy: 0.9684 - val_sens: 0.4180 - val_dice_coef_loss: 0.4454
#
# Epoch 00005: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_5_0.172083.hdf5
# Epoch 6/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1734 - accuracy: 0.9901 - sens: 0.8207 - dice_coef_loss: 0.1734 - val_loss: 0.4662 - val_accuracy: 0.9677 - val_sens: 0.3949 - val_dice_coef_loss: 0.4658
#
# Epoch 00006: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_6_0.173033.hdf5
# Epoch 7/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1709 - accuracy: 0.9902 - sens: 0.8234 - dice_coef_loss: 0.1709 - val_loss: 0.4415 - val_accuracy: 0.9684 - val_sens: 0.4272 - val_dice_coef_loss: 0.4413
#
# Epoch 00007: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_7_0.172294.hdf5
# Epoch 8/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1726 - accuracy: 0.9901 - sens: 0.8208 - dice_coef_loss: 0.1726 - val_loss: 0.4561 - val_accuracy: 0.9681 - val_sens: 0.4055 - val_dice_coef_loss: 0.4556
#
# Epoch 00008: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_8_0.170979.hdf5
# Epoch 9/50
# 2161/2161 [==============================] - 772s 357ms/step - loss: 0.1676 - accuracy: 0.9903 - sens: 0.8257 - dice_coef_loss: 0.1676 - val_loss: 0.4608 - val_accuracy: 0.9681 - val_sens: 0.3995 - val_dice_coef_loss: 0.4607
#
# Epoch 00009: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_9_0.171121.hdf5
# Epoch 10/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1702 - accuracy: 0.9903 - sens: 0.8221 - dice_coef_loss: 0.1702 - val_loss: 0.4658 - val_accuracy: 0.9679 - val_sens: 0.3944 - val_dice_coef_loss: 0.4655
#
# Epoch 00010: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_10_0.171924.hdf5
# Epoch 11/50
# 2161/2161 [==============================] - 772s 357ms/step - loss: 0.1751 - accuracy: 0.9898 - sens: 0.8191 - dice_coef_loss: 0.1751 - val_loss: 0.4445 - val_accuracy: 0.9683 - val_sens: 0.4198 - val_dice_coef_loss: 0.4443
#
# Epoch 00011: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_11_0.172412.hdf5
# Epoch 12/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1663 - accuracy: 0.9907 - sens: 0.8266 - dice_coef_loss: 0.1663 - val_loss: 0.5027 - val_accuracy: 0.9665 - val_sens: 0.3559 - val_dice_coef_loss: 0.5025
#
# Epoch 00012: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_12_0.168635.hdf5
# Epoch 13/50
# 2161/2161 [==============================] - 776s 359ms/step - loss: 0.1686 - accuracy: 0.9904 - sens: 0.8238 - dice_coef_loss: 0.1686 - val_loss: 0.4536 - val_accuracy: 0.9683 - val_sens: 0.4067 - val_dice_coef_loss: 0.4533
#
# Epoch 00013: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_13_0.169366.hdf5
# Epoch 14/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1655 - accuracy: 0.9905 - sens: 0.8258 - dice_coef_loss: 0.1655 - val_loss: 0.5133 - val_accuracy: 0.9659 - val_sens: 0.3470 - val_dice_coef_loss: 0.5130
#
# Epoch 00014: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_14_0.165797.hdf5
# Epoch 15/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1669 - accuracy: 0.9904 - sens: 0.8257 - dice_coef_loss: 0.1669 - val_loss: 0.4466 - val_accuracy: 0.9685 - val_sens: 0.4157 - val_dice_coef_loss: 0.4463
#
# Epoch 00015: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_15_0.168012.hdf5
# Epoch 16/50
# 2161/2161 [==============================] - 775s 359ms/step - loss: 0.1661 - accuracy: 0.9904 - sens: 0.8256 - dice_coef_loss: 0.1661 - val_loss: 0.4596 - val_accuracy: 0.9680 - val_sens: 0.4020 - val_dice_coef_loss: 0.4593
#
# Epoch 00016: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_16_0.166515.hdf5
# Epoch 17/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1653 - accuracy: 0.9906 - sens: 0.8256 - dice_coef_loss: 0.1653 - val_loss: 0.4695 - val_accuracy: 0.9673 - val_sens: 0.3946 - val_dice_coef_loss: 0.4691
#
# Epoch 00017: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_17_0.166724.hdf5
# Epoch 18/50
# 2161/2161 [==============================] - 772s 357ms/step - loss: 0.1646 - accuracy: 0.9906 - sens: 0.8279 - dice_coef_loss: 0.1646 - val_loss: 0.4855 - val_accuracy: 0.9665 - val_sens: 0.3764 - val_dice_coef_loss: 0.4852
#
# Epoch 00018: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_18_0.165478.hdf5
# Epoch 19/50
# 2161/2161 [==============================] - 772s 357ms/step - loss: 0.1687 - accuracy: 0.9905 - sens: 0.8214 - dice_coef_loss: 0.1687 - val_loss: 0.4652 - val_accuracy: 0.9678 - val_sens: 0.3966 - val_dice_coef_loss: 0.4648
#
# Epoch 00019: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_19_0.164588.hdf5
# Epoch 20/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1630 - accuracy: 0.9908 - sens: 0.8280 - dice_coef_loss: 0.1630 - val_loss: 0.4532 - val_accuracy: 0.9682 - val_sens: 0.4082 - val_dice_coef_loss: 0.4529
#
# Epoch 00020: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_20_0.165377.hdf5
# Epoch 21/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1661 - accuracy: 0.9907 - sens: 0.8243 - dice_coef_loss: 0.1661 - val_loss: 0.4770 - val_accuracy: 0.9672 - val_sens: 0.3830 - val_dice_coef_loss: 0.4767
#
# Epoch 00021: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_21_0.165636.hdf5
# Epoch 22/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1597 - accuracy: 0.9909 - sens: 0.8306 - dice_coef_loss: 0.1597 - val_loss: 0.5153 - val_accuracy: 0.9660 - val_sens: 0.3455 - val_dice_coef_loss: 0.5149
#
# Epoch 00022: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_22_0.164132.hdf5
# Epoch 23/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1642 - accuracy: 0.9906 - sens: 0.8269 - dice_coef_loss: 0.1642 - val_loss: 0.4943 - val_accuracy: 0.9666 - val_sens: 0.3659 - val_dice_coef_loss: 0.4941
#
# Epoch 00023: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_23_0.162757.hdf5
# Epoch 24/50
# 2161/2161 [==============================] - 775s 359ms/step - loss: 0.1640 - accuracy: 0.9908 - sens: 0.8275 - dice_coef_loss: 0.1640 - val_loss: 0.4526 - val_accuracy: 0.9682 - val_sens: 0.4086 - val_dice_coef_loss: 0.4522
#
# Epoch 00024: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_24_0.165983.hdf5
# Epoch 25/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1607 - accuracy: 0.9909 - sens: 0.8295 - dice_coef_loss: 0.1607 - val_loss: 0.4442 - val_accuracy: 0.9686 - val_sens: 0.4186 - val_dice_coef_loss: 0.4438
#
# Epoch 00025: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_25_0.162852.hdf5
# Epoch 26/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1595 - accuracy: 0.9910 - sens: 0.8318 - dice_coef_loss: 0.1595 - val_loss: 0.4477 - val_accuracy: 0.9688 - val_sens: 0.4118 - val_dice_coef_loss: 0.4474
#
# Epoch 00026: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_26_0.161414.hdf5
# Epoch 27/50
# 2161/2161 [==============================] - 772s 357ms/step - loss: 0.1613 - accuracy: 0.9910 - sens: 0.8288 - dice_coef_loss: 0.1613 - val_loss: 0.4572 - val_accuracy: 0.9683 - val_sens: 0.4035 - val_dice_coef_loss: 0.4570
#
# Epoch 00027: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_27_0.160219.hdf5
# Epoch 28/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1605 - accuracy: 0.9910 - sens: 0.8302 - dice_coef_loss: 0.1605 - val_loss: 0.4688 - val_accuracy: 0.9677 - val_sens: 0.3912 - val_dice_coef_loss: 0.4686
#
# Epoch 00028: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_28_0.161602.hdf5
# Epoch 29/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1597 - accuracy: 0.9912 - sens: 0.8304 - dice_coef_loss: 0.1597 - val_loss: 0.4510 - val_accuracy: 0.9684 - val_sens: 0.4090 - val_dice_coef_loss: 0.4508
#
# Epoch 00029: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_29_0.161993.hdf5
# Epoch 30/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1601 - accuracy: 0.9910 - sens: 0.8310 - dice_coef_loss: 0.1601 - val_loss: 0.4457 - val_accuracy: 0.9686 - val_sens: 0.4159 - val_dice_coef_loss: 0.4454
#
# Epoch 00030: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_30_0.162774.hdf5
# Epoch 31/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1634 - accuracy: 0.9909 - sens: 0.8265 - dice_coef_loss: 0.1634 - val_loss: 0.7255 - val_accuracy: 0.9589 - val_sens: 0.1828 - val_dice_coef_loss: 0.7250
#
# Epoch 00031: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_31_0.162453.hdf5
# Epoch 32/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1646 - accuracy: 0.9908 - sens: 0.8252 - dice_coef_loss: 0.1646 - val_loss: 0.4761 - val_accuracy: 0.9675 - val_sens: 0.3814 - val_dice_coef_loss: 0.4758
#
# Epoch 00032: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_32_0.161581.hdf5
# Epoch 33/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1604 - accuracy: 0.9909 - sens: 0.8295 - dice_coef_loss: 0.1604 - val_loss: 0.4549 - val_accuracy: 0.9682 - val_sens: 0.4053 - val_dice_coef_loss: 0.4545
#
# Epoch 00033: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_33_0.161491.hdf5
# Epoch 34/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1564 - accuracy: 0.9911 - sens: 0.8329 - dice_coef_loss: 0.1564 - val_loss: 0.4524 - val_accuracy: 0.9683 - val_sens: 0.4081 - val_dice_coef_loss: 0.4522
#
# Epoch 00034: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_34_0.160031.hdf5
# Epoch 35/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1545 - accuracy: 0.9911 - sens: 0.8340 - dice_coef_loss: 0.1545 - val_loss: 0.5107 - val_accuracy: 0.9663 - val_sens: 0.3458 - val_dice_coef_loss: 0.5105
#
# Epoch 00035: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_35_0.159154.hdf5
# Epoch 36/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1566 - accuracy: 0.9911 - sens: 0.8320 - dice_coef_loss: 0.1566 - val_loss: 0.4553 - val_accuracy: 0.9678 - val_sens: 0.4086 - val_dice_coef_loss: 0.4550
#
# Epoch 00036: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_36_0.159151.hdf5
# Epoch 37/50
# 2161/2161 [==============================] - 777s 360ms/step - loss: 0.1587 - accuracy: 0.9912 - sens: 0.8302 - dice_coef_loss: 0.1587 - val_loss: 0.4437 - val_accuracy: 0.9684 - val_sens: 0.4193 - val_dice_coef_loss: 0.4435
#
# Epoch 00037: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_37_0.160913.hdf5
# Epoch 38/50
# 2161/2161 [==============================] - 777s 359ms/step - loss: 0.1580 - accuracy: 0.9912 - sens: 0.8313 - dice_coef_loss: 0.1580 - val_loss: 0.5036 - val_accuracy: 0.9665 - val_sens: 0.3550 - val_dice_coef_loss: 0.5034
#
# Epoch 00038: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_38_0.158197.hdf5
# Epoch 39/50
# 2161/2161 [==============================] - 779s 361ms/step - loss: 0.1556 - accuracy: 0.9911 - sens: 0.8326 - dice_coef_loss: 0.1556 - val_loss: 0.4740 - val_accuracy: 0.9672 - val_sens: 0.3862 - val_dice_coef_loss: 0.4739
#
# Epoch 00039: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_39_0.157885.hdf5
# Epoch 40/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1577 - accuracy: 0.9912 - sens: 0.8314 - dice_coef_loss: 0.1577 - val_loss: 0.4770 - val_accuracy: 0.9673 - val_sens: 0.3813 - val_dice_coef_loss: 0.4767
#
# Epoch 00040: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_40_0.157615.hdf5
# Epoch 41/50
# 2161/2161 [==============================] - 777s 360ms/step - loss: 0.1525 - accuracy: 0.9911 - sens: 0.8364 - dice_coef_loss: 0.1525 - val_loss: 0.4652 - val_accuracy: 0.9679 - val_sens: 0.3941 - val_dice_coef_loss: 0.4650
#
# Epoch 00041: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_41_0.155305.hdf5
# Epoch 42/50
# 2161/2161 [==============================] - 777s 360ms/step - loss: 0.1590 - accuracy: 0.9911 - sens: 0.8284 - dice_coef_loss: 0.1590 - val_loss: 0.4652 - val_accuracy: 0.9678 - val_sens: 0.3966 - val_dice_coef_loss: 0.4650
# Epoch 00042: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_42_0.158468.hdf5
# Epoch 43/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1583 - accuracy: 0.9913 - sens: 0.8294 - dice_coef_loss: 0.1583 - val_loss: 0.4533 - val_accuracy: 0.9682 - val_sens: 0.4080 - val_dice_coef_loss: 0.4531
#
# Epoch 00043: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_43_0.156978.hdf5
# Epoch 44/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1550 - accuracy: 0.9912 - sens: 0.8322 - dice_coef_loss: 0.1550 - val_loss: 0.5305 - val_accuracy: 0.9656 - val_sens: 0.3297 - val_dice_coef_loss: 0.5301
#
# Epoch 00044: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_44_0.155512.hdf5
# Epoch 45/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1534 - accuracy: 0.9914 - sens: 0.8345 - dice_coef_loss: 0.1534 - val_loss: 0.4663 - val_accuracy: 0.9681 - val_sens: 0.3909 - val_dice_coef_loss: 0.4662
#
# Epoch 00045: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_45_0.156088.hdf5
# Epoch 46/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1563 - accuracy: 0.9913 - sens: 0.8308 - dice_coef_loss: 0.1563 - val_loss: 0.4774 - val_accuracy: 0.9672 - val_sens: 0.3817 - val_dice_coef_loss: 0.4772
#
# Epoch 00046: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_46_0.155254.hdf5
# Epoch 47/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1570 - accuracy: 0.9914 - sens: 0.8309 - dice_coef_loss: 0.1570 - val_loss: 0.4619 - val_accuracy: 0.9681 - val_sens: 0.3963 - val_dice_coef_loss: 0.4616
#
# Epoch 00047: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_47_0.156016.hdf5
# Epoch 48/50
# 2161/2161 [==============================] - 774s 358ms/step - loss: 0.1540 - accuracy: 0.9914 - sens: 0.8339 - dice_coef_loss: 0.1540 - val_loss: 0.4623 - val_accuracy: 0.9679 - val_sens: 0.3981 - val_dice_coef_loss: 0.4620
#
# Epoch 00048: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_48_0.155181.hdf5
# Epoch 49/50
# 2161/2161 [==============================] - 773s 358ms/step - loss: 0.1531 - accuracy: 0.9914 - sens: 0.8349 - dice_coef_loss: 0.1531 - val_loss: 0.4725 - val_accuracy: 0.9675 - val_sens: 0.3874 - val_dice_coef_loss: 0.4724
#
# Epoch 00049: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_49_0.154663.hdf5
# Epoch 50/50
# 2161/2161 [==============================] - 777s 360ms/step - loss: 0.1530 - accuracy: 0.9915 - sens: 0.8350 - dice_coef_loss: 0.1530 - val_loss: 0.4507 - val_accuracy: 0.9683 - val_sens: 0.4119 - val_dice_coef_loss: 0.4504
#
# Epoch 00050: saving model to C:/Users/s_wnsgk4041/crack_segmentation_dataset/crack_check\final_50_0.156211.hdf5
# save model
# ------------------------------
# Creating test images...
# ------------------------------
# 0/1695
# 100/1695
# 200/1695
# 300/1695
# 400/1695
# 500/1695
# 600/1695
# 700/1695
# 800/1695
# 900/1695
# 1000/1695
# 1100/1695
# 1200/1695
# 1300/1695
# 1400/1695
# 1500/1695
# 1600/1695
# img :  255.0
# mask :  255.0
# ------------------------------
# normalization start...
# ------------------------------
# img :  1.0
# mask :  1.0
# mask :  0.0
# loading done
# predict test data
# 424/424 [==============================] - 50s 116ms/step
# (1695, 512, 512, 1)
# [0.0000000e+00 1.1754997e-38 1.1755086e-38 ... 9.9999976e-01 9.9999988e-01
#  1.0000000e+00]
# ------------------------------
# Saving test images...
# ------------------------------
